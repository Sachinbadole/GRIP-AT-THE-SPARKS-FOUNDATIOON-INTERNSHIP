# %% [markdown]
# # THE SPARKS FOUNDATION INTERNSHIP TASK 05 TO EXPLORE BUSINESS ANALYTICS

# %% [markdown]
# # PROBLEM : What all business problems you can derive by performing exploratory data analysis on the data?

# %%
#importing libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# # DATA PREPROCESSING

# %%
#collecting the dataset
data = pd.read_csv('SampleSuperstore.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# Country         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Postal Code     9994 non-null int64
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data
# Out:
#            Ship Mode      Segment        Country             City  \
# 0       Second Class     Consumer  United States        Henderson
# 1       Second Class     Consumer  United States        Henderson
# 2       Second Class    Corporate  United States      Los Angeles
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 4     Standard Class     Consumer  United States  Fort Lauderdale
# 5     Standard Class     Consumer  United States      Los Angeles
# 6     Standard Class     Consumer  United States      Los Angeles
# 7     Standard Class     Consumer  United States      Los Angeles
# 8     Standard Class     Consumer  United States      Los Angeles
# 9     Standard Class     Consumer  United States      Los Angeles
# 10    Standard Class     Consumer  United States      Los Angeles
# 11    Standard Class     Consumer  United States      Los Angeles
# 12    Standard Class     Consumer  United States          Concord
# ...

# %% [markdown]
# # Data Cleaning

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 9964    False
# 9965    False
# 9966    False
# 9967    False
# 9968    False
# 9969    False
# 9970    False
# 9971    False
# 9972    False
# 9973    False
# 9974    False
# 9975    False
# 9976    False
# 9977    False
# 9978    False
# 9979    False
# 9980    False
# 9981    False
# 9982    False
# 9983    False
# 9984    False
# 9985    False
# 9986    False
# 9987    False
# 9988    False
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# ...

# %%
data.duplicated().sum()
# Out:
# 17

# %%
data[data.duplicated()==True]
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 3406  Standard Class  Home Office  United States       Columbus          Ohio
# 3670  Standard Class     Consumer  United States          Salem        Oregon
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4553  Standard Class     Consumer  United States  San Francisco    California
# 5905        Same Day  Home Office  United States  San Francisco    California
# 6146  Standard Class    Corporate  United States  San Francisco    California
# 6334  Standard Class     Consumer  United States  New York City      New York
# 6357  Standard Class    Corporate  United States        Seattle    Washington
# 7608  Standard Class     Consumer  United States  San Francisco    California
# 7735  Standard Class    Corporate  United States        Seattle    Washington
# ...

# %%
data.isna()
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# 5         False    False    False  False  False        False   False
# 6         False    False    False  False  False        False   False
# 7         False    False    False  False  False        False   False
# 8         False    False    False  False  False        False   False
# 9         False    False    False  False  False        False   False
# 10        False    False    False  False  False        False   False
# 11        False    False    False  False  False        False   False
# 12        False    False    False  False  False        False   False
# ...

# %%
data.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# In the Data Cleaning process, it is concluded that data is cleaned.
# Duplicated rows shown in the output cannot be removed because if we do this it will be misleading.
# And all rows and columns are filled with details, and their is no Nan value is dataset.

# %% [markdown]
# # Univariate Analysis

# %%
    data
# Out:
#            Ship Mode      Segment        Country             City  \
# 0       Second Class     Consumer  United States        Henderson
# 1       Second Class     Consumer  United States        Henderson
# 2       Second Class    Corporate  United States      Los Angeles
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 4     Standard Class     Consumer  United States  Fort Lauderdale
# 5     Standard Class     Consumer  United States      Los Angeles
# 6     Standard Class     Consumer  United States      Los Angeles
# 7     Standard Class     Consumer  United States      Los Angeles
# 8     Standard Class     Consumer  United States      Los Angeles
# 9     Standard Class     Consumer  United States      Los Angeles
# 10    Standard Class     Consumer  United States      Los Angeles
# 11    Standard Class     Consumer  United States      Los Angeles
# 12    Standard Class     Consumer  United States          Concord
# ...

# %% [markdown]
# Analysis of shipping mode

# %%
sns.countplot(data['Ship Mode'])

# %%
data['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %% [markdown]
# Analysis of Segments

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
sns.countplot(data['Segment'])

# %% [markdown]
# Analysis of Customer visiting Different City stores

# %%
data['City'].value_counts()
# Out:
# New York City     915
# Los Angeles       747
# Philadelphia      537
# San Francisco     510
# Seattle           428
# Houston           377
# Chicago           314
# Columbus          222
# San Diego         170
# Springfield       163
# Dallas            157
# Jacksonville      125
# Detroit           115
# Newark             95
# Richmond           90
# Jackson            82
# Columbia           81
# Aurora             68
# Phoenix            63
# Long Beach         61
# Arlington          60
# San Antonio        59
# Louisville         57
# Miami              57
# Rochester          53
# Charlotte          52
# Henderson          51
# Lakewood           49
# Lancaster          46
# Fairfield          45
#                  ...
# Pico Rivera         1
# La Quinta           1
# Vacaville           1
# Margate             1
# Rock Hill           1
# Jefferson City      1
# Orland Park         1
# Glenview            1
# Ormond Beach        1
# Ontario             1
# ...

# %%
plt.figure(figsize=(30,10))
sns.countplot(y='City', data=data)

# %% [markdown]
# Analysis of Regions

# %%
data['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='Region', data=data)

# %% [markdown]
# Analysis of Category

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='Category', data=data)

# %% [markdown]
# Analysis of Sub-Category

# %%
data['Sub-Category'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Bookcases
# 1            Chairs
# 2            Labels
# 3            Tables
# 4           Storage
# 5       Furnishings
# 6               Art
# 7            Phones
# 8           Binders
# 9        Appliances
# 10           Tables
# 11           Phones
# 12            Paper
# 13          Binders
# 14       Appliances
# 15          Binders
# 16          Storage
# 17          Storage
# 18              Art
# 19           Phones
# 20          Binders
# 21              Art
# 22       Appliances
# 23           Chairs
# 24           Tables
# 25          Binders
# 26      Accessories
# 27        Bookcases
# 28          Binders
# 29      Furnishings
#            ...
# 9964    Furnishings
# 9965          Paper
# 9966      Envelopes
# 9967        Binders
# 9968        Binders
# 9969     Appliances
# 9970        Binders
# 9971            Art
# 9972      Envelopes
# 9973         Phones
# 9974            Art
# 9975          Paper
# ...

# %%
plt.figure(figsize=(16,6))
sns.countplot(x='Sub-Category', data=data)

# %% [markdown]
# # Conclusion:-
# Conclusion is based on the univariate analysis,
# 1)Analysis of ship mode states that stores uses standard class more often then other modes, and same day shipping mode is less.
# 2)Analysis of segemt shows that consumer visit the store more often.
# 3)In the analysis of region, west region stores has more number of customers than others.
# 4)Analysis of category shows office supplies is more sold in all the region.
# 5) Analysis of sub-category shows that blinders are sold more than others.

# %%
data['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %% [markdown]
# # Bi-variate Analysis

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# Sales and profit of Ship mode

# %%
data.groupby('Ship Mode')['Sales'].sum()
# Out:
# Ship Mode
# First Class       3.514284e+05
# Same Day          1.283631e+05
# Second Class      4.591936e+05
# Standard Class    1.358216e+06
# Name: Sales, dtype: float64

# %%
sns.barplot(x=data['Ship Mode'], y=data['Sales'])

# %%
data.groupby('Ship Mode')['Profit'].sum()
# Out:
# Ship Mode
# First Class        48969.8399
# Same Day           15891.7589
# Second Class       57446.6354
# Standard Class    164088.7875
# Name: Profit, dtype: float64

# %%
sns.barplot(x=data['Ship Mode'], y=data['Profit'])

# %% [markdown]
# Analysis of ship-mode and segment of the dataset

# %%
sns.catplot('Ship Mode', hue='Segment', data=data, kind='count', aspect=1.5, palette ='Set1')

# %% [markdown]
# It is observed that consumer choose standard class ship mode more often

# %%
sns.catplot('Ship Mode', hue='Region', data=data, kind='count', aspect=1.5, palette ='Set1')

# %%
sns.catplot('Ship Mode', hue='Category', data=data, kind='count', aspect=1.5, palette ='Set1')

# %% [markdown]
# It is observed that Furniture, office supplies, Technology all are shipped in using standard class more often.

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.groupby('Ship Mode')['Quantity'].sum()
# Out:
# Ship Mode
# First Class        5693
# Same Day           1960
# Second Class       7423
# Standard Class    22797
# Name: Quantity, dtype: int64

# %% [markdown]
# As usual Standard class has choose more often

# %% [markdown]
# Analyzing profit and sales of segment>

# %%
data.groupby('Segment')["Profit"].sum()
# Out:
# Segment
# Consumer       134119.2092
# Corporate       91979.1340
# Home Office     60298.6785
# Name: Profit, dtype: float64

# %% [markdown]
# It is observed that consumer provided more profit to the stores

# %%
data.groupby('Segment')["Sales"].sum()
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
data.groupby('Segment')['Discount'].sum()
# Out:
# Segment
# Consumer       820.91
# Corporate      477.85
# Home Office    262.33
# Name: Discount, dtype: float64

# %% [markdown]
# Its is observed that most profit is gain from consumer segment, most sale has noted in corporated segment and most discount is given to Consumer segment.

# %% [markdown]
# State Wise profit and sales

# %%
#plt.figure(figsize(20,10)
s_d=data.groupby('State')["Profit","Sales"].sum()
# Out:
#                           Profit        Sales
# State
# Alabama                5786.8253   19510.6400
# Arizona               -3427.9246   35282.0010
# Arkansas               4008.6871   11678.1300
# California            76381.3871  457687.6315
# Colorado              -6527.8579   32108.1180
# Connecticut            3511.4918   13384.3570
# Delaware               9977.3748   27451.0690
# District of Columbia   1059.5893    2865.0200
# Florida               -3399.3017   89473.7080
# Georgia               16250.0433   49095.8400
# Idaho                   826.7231    4382.4860
# Illinois             -12607.8870   80166.1010
# Indiana               18382.9363   53555.3600
# Iowa                   1183.8119    4579.7600
# Kansas                  836.4435    2914.3100
# Kentucky              11199.6966   36591.7500
# Louisiana              2196.1023    9217.0300
# Maine                   454.4862    1270.5300
# Maryland               7031.1788   23705.5230
# ...

# %% [markdown]
# Even though the sales are High in states like Arizona,Colorada,Florida,llinois,North carolina, ohio,Pennsylvania, Tennesse,Texas, the shop is generating loss instead of profit

# %%
data.groupby('City').max()['Profit'].plot.bar(figsize=(15,7))

# %% [markdown]
# Region wise profit and sales

# %%
data.groupby('Region')["Profit","Sales"].sum()
# Out:
#               Profit        Sales
# Region
# Central   39706.3625  501239.8908
# East      91522.7800  678781.2400
# South     46749.4303  391721.9050
# West     108418.4489  725457.8245

# %%
data.groupby('Region')["Profit","Sales"].max()
# Out:
#             Profit      Sales
# Region
# Central  8399.9760  17499.950
# East     5039.9856  11199.968
# South    3177.4750  22638.480
# West     6719.9808  13999.960

# %%
data.groupby('Region')["Profit","Sales"].min()
# Out:
#             Profit  Sales
# Region
# Central -3701.8928  0.444
# East    -6599.9780  0.852
# South   -3839.9904  1.167
# West    -3399.9800  0.990

# %%
data.groupby('Region')['Discount'].sum()
# Out:
# Region
# Central    558.34
# East       414.00
# South      238.55
# West       350.20
# Name: Discount, dtype: float64

# %% [markdown]
# It is observed that west region has more profit and sales as per data, maximum amount of profit is generated in central region and maximum sales noticed in south region and minimum profit has been noticed from east region minimum sales is noticed from central region. It is also noticed that most discount is given by central region and central region has gain most profit.

# %% [markdown]
# Category wise profit,quantity and sale

# %%
data.groupby('Category')['Quantity'].sum()
# Out:
# Category
# Furniture           8028
# Office Supplies    22906
# Technology          6939
# Name: Quantity, dtype: int64

# %%
data.groupby('Category')['Profit'].sum()
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
data.groupby('Category')['Sales'].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
data.groupby('Category')['Sales'].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %% [markdown]
# It is noticed that most selling category is office supplies but most profit is gained by selling technology items.

# %%
data.groupby('Category')['Discount'].sum()
# Out:
# Category
# Furniture          368.89
# Office Supplies    947.80
# Technology         244.40
# Name: Discount, dtype: float64

# %% [markdown]
# More discount is offered on office supplies.

# %% [markdown]
# Sub-category analysis

# %%
s_d=data.groupby('Sub-Category')['Quantity'].sum()

# %%
s_d2=s_d.sort_values()

# %%
s_d2
# Out:
# Sub-Category
# Copiers         234
# Machines        440
# Supplies        647
# Bookcases       868
# Envelopes       906
# Fasteners       914
# Tables         1241
# Labels         1400
# Appliances     1729
# Chairs         2356
# Accessories    2976
# Art            3000
# Storage        3158
# Phones         3289
# Furnishings    3563
# Paper          5178
# Binders        5974
# Name: Quantity, dtype: int64

# %% [markdown]
# Binders,paper,furnishings,phones,storage,art are most solded sub-categories.
# And copiers , machines, supplies, bookcases are least sold.
# This is may be problem behind less profit because we have only 17 products to offer in 50 cities of USA.
# People need big market which has more products which can sattisfy their needs, offering them more products will help the company to gain more profit.
# products which are most sold can be kept closer so that people get that easily and their will be no rush in the supermarket.

# %%
s_a=data.groupby('Sub-Category')['Profit'].sum()

# %%
S_A=s_a.sort_values()

# %%
S_A
# Out:
# Sub-Category
# Tables        -17725.4811
# Bookcases      -3472.5560
# Supplies       -1189.0995
# Fasteners        949.5182
# Machines        3384.7569
# Labels          5546.2540
# Art             6527.7870
# Envelopes       6964.1767
# Furnishings    13059.1436
# Appliances     18138.0054
# Storage        21278.8264
# Chairs         26590.1663
# Binders        30221.7633
# Paper          34053.5693
# Accessories    41936.6357
# Phones         44515.7306
# Copiers        55617.8249
# Name: Profit, dtype: float64

# %% [markdown]
# It is observed that copiers which has sold less gives maximum profit among all products.
# Few Products like Supplies, bookcases, tables should be removed as they are less sold and has negative profit(loss).
# where products like machine, enveloped, fasteners has on an average profit as compared to quantity sold.

# %%
data2=data.groupby('Sub-Category')['Sales'].sum()

# %%
data3=data2.sort_values()

# %%
data3
# Out:
# Sub-Category
# Fasteners        3024.2800
# Labels          12486.3120
# Envelopes       16476.4020
# Art             27118.7920
# Supplies        46673.5380
# Paper           78479.2060
# Furnishings     91705.1640
# Appliances     107532.1610
# Bookcases      114879.9963
# Copiers        149528.0300
# Accessories    167380.3180
# Machines       189238.6310
# Binders        203412.7330
# Tables         206965.5320
# Storage        223843.6080
# Chairs         328449.1030
# Phones         330007.0540
# Name: Sales, dtype: float64

# %% [markdown]
# Analysis of discount and profit.

# %%
sns.scatterplot(data['Discount'], data['Profit'])
sns.regplot(data['Discount'], data['Profit'])

# %% [markdown]
# Graph shows that higher the Discount lesser the profit

# %% [markdown]
# Analysis of Discount and sales

# %%
sns.scatterplot(data['Discount'], data['Sales'])
sns.regplot(data['Discount'], data['Sales'])

# %% [markdown]
# More discount also affect sales of the store

# %% [markdown]
# Thank You

# %% [markdown]
# Thats my Analysis and observation on the dataset.
